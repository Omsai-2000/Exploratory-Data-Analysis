# %% [markdown]
# <a href="https://colab.research.google.com/github/Omsai-2000/Exploratory-Data-Analysis/blob/main/Indian_Houses_Analysis_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# importing dataset
df=pd.read_csv('IndianHouses.csv')
df.head()
# Out:
#     Area  BHK  Bathroom      Furnishing  \
# 0  800.0    3       2.0  Semi-Furnished
# 1  750.0    2       2.0  Semi-Furnished
# 2  950.0    2       2.0       Furnished
# 3  600.0    2       2.0  Semi-Furnished
# 4  650.0    2       2.0  Semi-Furnished
#
#                                             Locality  Parking     Price  \
# 0                                   Rohini Sector 25      1.0   6500000
# 1             J R Designers Floors, Rohini Sector 24      1.0   5000000
# 2                Citizen Apartment, Rohini Sector 13      1.0  15500000
# 3                                   Rohini Sector 24      1.0   4200000
# 4  Rohini Sector 24 carpet area 650 sqft status R...      1.0   6200000
#
#           Status   Transaction           Type  Per_Sqft
# 0  Ready_to_move  New_Property  Builder_Floor       NaN
# 1  Ready_to_move  New_Property      Apartment    6667.0
# 2  Ready_to_move        Resale      Apartment    6667.0
# 3  Ready_to_move        Resale  Builder_Floor    6667.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Area         1259 non-null   float64
#  1   BHK          1259 non-null   int64
#  2   Bathroom     1257 non-null   float64
#  3   Furnishing   1254 non-null   object
#  4   Locality     1259 non-null   object
#  5   Parking      1226 non-null   float64
#  6   Price        1259 non-null   int64
#  7   Status       1259 non-null   object
#  8   Transaction  1259 non-null   object
#  9   Type         1254 non-null   object
#  10  Per_Sqft     1018 non-null   float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 108.3+ KB

# %%
df.describe()
# Out:
#                Area          BHK     Bathroom      Parking         Price  \
# count   1259.000000  1259.000000  1257.000000  1226.000000  1.259000e+03
# mean    1466.452724     2.796664     2.556086     1.935563  2.130670e+07
# std     1568.055040     0.954425     1.042220     6.279212  2.560115e+07
# min       28.000000     1.000000     1.000000     1.000000  1.000000e+06
# 25%      800.000000     2.000000     2.000000     1.000000  5.700000e+06
# 50%     1200.000000     3.000000     2.000000     1.000000  1.420000e+07
# 75%     1700.000000     3.000000     3.000000     2.000000  2.550000e+07
# max    24300.000000    10.000000     7.000000   114.000000  2.400000e+08
#
#             Per_Sqft
# count    1018.000000
# mean    15690.136542
# std     21134.738568
# min      1259.000000
# 25%      6364.000000
# 50%     11291.500000
# 75%     18000.000000
# max    183333.000000

# %%
df.isnull().sum()
# Out:
# Area             0
# BHK              0
# Bathroom         2
# Furnishing       5
# Locality         0
# Parking         33
# Price            0
# Status           0
# Transaction      0
# Type             5
# Per_Sqft       241
# dtype: int64

# %%
df.shape
# Out:
# (1259, 11)

# %%
df[df['Bathroom'].isnull()]
# Out:
#        Area  BHK  Bathroom   Furnishing        Locality  Parking     Price  \
# 30   1500.0    1       NaN  Unfurnished  Lajpat Nagar 2      NaN  13500000
# 120  1500.0    1       NaN  Unfurnished  Lajpat Nagar 2      NaN  13500000
#
#             Status Transaction       Type  Per_Sqft
# 30   Ready_to_move      Resale  Apartment       NaN
# 120  Ready_to_move      Resale  Apartment       NaN

# %%
df.BHK.unique()
# Out:
# array([ 3,  2,  4,  1,  6,  5,  7, 10])

# %%
sns.heatmap(df.isnull(),cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
df['Bathroom'].fillna(1,inplace=True)

# %%
df['Bathroom'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Area             0
# BHK              0
# Bathroom         0
# Furnishing       5
# Locality         0
# Parking         33
# Price            0
# Status           0
# Transaction      0
# Type             5
# Per_Sqft       241
# dtype: int64

# %%
df[df['Furnishing'].isnull()]
# Out:
#        Area  BHK  Bathroom Furnishing  \
# 509   450.0    2       2.0        NaN
# 510   540.0    5       2.0        NaN
# 511  1350.0    3       3.0        NaN
# 512  2250.0    3       2.0        NaN
# 719  1500.0    3       2.0        NaN
#
#                                               Locality  Parking     Price  \
# 509                             Gandhi Nagar, Shahdara      NaN   2900000
# 510                             Gandhi Nagar, Shahdara      NaN  17000000
# 511                             Gandhi Nagar, Shahdara      NaN  25000000
# 512                             Gandhi Nagar, Shahdara      NaN  10000000
# 719  Sarita Vihar, Mathura Road carpet area 1500 sq...      1.0  13500000
#
#             Status Transaction Type  Per_Sqft
# 509  Ready_to_move      Resale  NaN   58000.0
# 510  Ready_to_move      Resale  NaN   58000.0
# 511  Ready_to_move      Resale  NaN   18519.0
# 512  Ready_to_move      Resale  NaN    4444.0
# 719  Ready_to_move      Resale  NaN       NaN

# %%
df.Furnishing.unique()
# Out:
# array(['Semi-Furnished', 'Furnished', 'Unfurnished', nan], dtype=object)

# %%
df.Furnishing.mode()
# Out:
# 0    Semi-Furnished
# Name: Furnishing, dtype: object

# %%
#df['Furnishing']=df['Furnishing'].map({'Unfurnished':0,'Semi-Furnished':1,'Furnished':2,'nan':1})

# %%
df['Furnishing'].value_counts()
# Out:
# Semi-Furnished    708
# Unfurnished       363
# Furnished         183
# Name: Furnishing, dtype: int64

# %%
df['Furnishing'].fillna('Semi-Furnishing',inplace=True)

# %%
df['Furnishing'].isnull().sum()
# Out:
# 0

# %%
df.head()
# Out:
#     Area  BHK  Bathroom      Furnishing  \
# 0  800.0    3       2.0  Semi-Furnished
# 1  750.0    2       2.0  Semi-Furnished
# 2  950.0    2       2.0       Furnished
# 3  600.0    2       2.0  Semi-Furnished
# 4  650.0    2       2.0  Semi-Furnished
#
#                                             Locality  Parking     Price  \
# 0                                   Rohini Sector 25      1.0   6500000
# 1             J R Designers Floors, Rohini Sector 24      1.0   5000000
# 2                Citizen Apartment, Rohini Sector 13      1.0  15500000
# 3                                   Rohini Sector 24      1.0   4200000
# 4  Rohini Sector 24 carpet area 650 sqft status R...      1.0   6200000
#
#           Status   Transaction           Type  Per_Sqft
# 0  Ready_to_move  New_Property  Builder_Floor       NaN
# 1  Ready_to_move  New_Property      Apartment    6667.0
# 2  Ready_to_move        Resale      Apartment    6667.0
# 3  Ready_to_move        Resale  Builder_Floor    6667.0
# ...

# %%
df.isnull().sum()
# Out:
# Area             0
# BHK              0
# Bathroom         0
# Furnishing       0
# Locality         0
# Parking         33
# Price            0
# Status           0
# Transaction      0
# Type             5
# Per_Sqft       241
# dtype: int64

# %%
df[df['Type'].isnull()]
# Out:
#        Area  BHK  Bathroom       Furnishing  \
# 509   450.0    2       2.0  Semi-Furnishing
# 510   540.0    5       2.0  Semi-Furnishing
# 511  1350.0    3       3.0  Semi-Furnishing
# 512  2250.0    3       2.0  Semi-Furnishing
# 719  1500.0    3       2.0  Semi-Furnishing
#
#                                               Locality  Parking     Price  \
# 509                             Gandhi Nagar, Shahdara      NaN   2900000
# 510                             Gandhi Nagar, Shahdara      NaN  17000000
# 511                             Gandhi Nagar, Shahdara      NaN  25000000
# 512                             Gandhi Nagar, Shahdara      NaN  10000000
# 719  Sarita Vihar, Mathura Road carpet area 1500 sq...      1.0  13500000
#
#             Status Transaction Type  Per_Sqft
# 509  Ready_to_move      Resale  NaN   58000.0
# 510  Ready_to_move      Resale  NaN   58000.0
# 511  Ready_to_move      Resale  NaN   18519.0
# 512  Ready_to_move      Resale  NaN    4444.0
# ...

# %%
df['Type'].unique()
# Out:
# array(['Builder_Floor', 'Apartment', nan], dtype=object)

# %%
df['Type'].value_counts()
# Out:
# Builder_Floor    661
# Apartment        593
# Name: Type, dtype: int64

# %%
df['Type'].fillna('Builder_Floor',inplace=True)

# %%
df.head()
# Out:
#     Area  BHK  Bathroom      Furnishing  \
# 0  800.0    3       2.0  Semi-Furnished
# 1  750.0    2       2.0  Semi-Furnished
# 2  950.0    2       2.0       Furnished
# 3  600.0    2       2.0  Semi-Furnished
# 4  650.0    2       2.0  Semi-Furnished
#
#                                             Locality  Parking     Price  \
# 0                                   Rohini Sector 25      1.0   6500000
# 1             J R Designers Floors, Rohini Sector 24      1.0   5000000
# 2                Citizen Apartment, Rohini Sector 13      1.0  15500000
# 3                                   Rohini Sector 24      1.0   4200000
# 4  Rohini Sector 24 carpet area 650 sqft status R...      1.0   6200000
#
#           Status   Transaction           Type  Per_Sqft
# 0  Ready_to_move  New_Property  Builder_Floor       NaN
# 1  Ready_to_move  New_Property      Apartment    6667.0
# 2  Ready_to_move        Resale      Apartment    6667.0
# 3  Ready_to_move        Resale  Builder_Floor    6667.0
# ...

# %%
df.isnull().sum()
# Out:
# Area             0
# BHK              0
# Bathroom         0
# Furnishing       0
# Locality         0
# Parking         33
# Price            0
# Status           0
# Transaction      0
# Type             0
# Per_Sqft       241
# dtype: int64

# %%
df['Parking'].unique()
# Out:
# array([  1.,   5.,   2.,  nan,   4.,   9.,   3.,  39.,  10., 114.])

# %%
df['Parking'].value_counts()
# Out:
# 1.0      796
# 2.0      341
# 3.0       54
# 4.0       16
# 5.0        7
# 39.0       7
# 114.0      3
# 9.0        1
# 10.0       1
# Name: Parking, dtype: int64

# %%
df['Parking'].fillna(1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Area             0
# BHK              0
# Bathroom         0
# Furnishing       0
# Locality         0
# Parking          0
# Price            0
# Status           0
# Transaction      0
# Type             0
# Per_Sqft       241
# dtype: int64

# %%
df[df['Per_Sqft'].isnull()]
# Out:
#         Area  BHK  Bathroom      Furnishing  \
# 0      800.0    3       2.0  Semi-Furnished
# 30    1500.0    1       1.0     Unfurnished
# 31     800.0    2       2.0     Unfurnished
# 32     900.0    2       2.0     Unfurnished
# 33    1080.0    3       2.0  Semi-Furnished
# ...      ...  ...       ...             ...
# 1185   900.0    2       2.0     Unfurnished
# 1199  2520.0    3       3.0     Unfurnished
# 1200  1700.0    3       4.0     Unfurnished
# 1229  2097.0    3       3.0     Unfurnished
# 1230  1250.0    3       3.0  Semi-Furnished
#
#                                        Locality  Parking     Price  \
# 0                              Rohini Sector 25      1.0   6500000
# 30                               Lajpat Nagar 2      1.0  13500000
# 31                               Lajpat Nagar 1      1.0  15000000
# 32                                 Lajpat Nagar      1.0  10500000
# 33                   Vikram Vihar, Lajpat Nagar      1.0  22500000
# ...

# %%
df['Per_Sqft'].fillna(0,inplace=True)

# %%
df.isnull().sum()
# Out:
# Area           0
# BHK            0
# Bathroom       0
# Furnishing     0
# Locality       0
# Parking        0
# Price          0
# Status         0
# Transaction    0
# Type           0
# Per_Sqft       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Area         1259 non-null   float64
#  1   BHK          1259 non-null   int64
#  2   Bathroom     1259 non-null   float64
#  3   Furnishing   1259 non-null   object
#  4   Locality     1259 non-null   object
#  5   Parking      1259 non-null   float64
#  6   Price        1259 non-null   int64
#  7   Status       1259 non-null   object
#  8   Transaction  1259 non-null   object
#  9   Type         1259 non-null   object
#  10  Per_Sqft     1259 non-null   float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 108.3+ KB

# %%
df['Furnishing'].unique()
# Out:
# array(['Semi-Furnished', 'Furnished', 'Unfurnished', 'Semi-Furnishing'],
#       dtype=object)

# %%
df['Furnishing']=df['Furnishing'].map({'Semi-Furnished':1,'Unfurnished':0,'Furnished':2,'Semi-Furnishing':1})
df.head()
# Out:
#     Area  BHK  Bathroom  Furnishing  \
# 0  800.0    3       2.0           1
# 1  750.0    2       2.0           1
# 2  950.0    2       2.0           2
# 3  600.0    2       2.0           1
# 4  650.0    2       2.0           1
#
#                                             Locality  Parking     Price  \
# 0                                   Rohini Sector 25      1.0   6500000
# 1             J R Designers Floors, Rohini Sector 24      1.0   5000000
# 2                Citizen Apartment, Rohini Sector 13      1.0  15500000
# 3                                   Rohini Sector 24      1.0   4200000
# 4  Rohini Sector 24 carpet area 650 sqft status R...      1.0   6200000
#
#           Status   Transaction           Type  Per_Sqft
# 0  Ready_to_move  New_Property  Builder_Floor       0.0
# 1  Ready_to_move  New_Property      Apartment    6667.0
# 2  Ready_to_move        Resale      Apartment    6667.0
# 3  Ready_to_move        Resale  Builder_Floor    6667.0
# ...

# %%
df['Locality'].unique()
# Out:
# array(['Rohini Sector 25', 'J R Designers Floors, Rohini Sector 24',
#        'Citizen Apartment, Rohini Sector 13', 'Rohini Sector 24',
#        'Rohini Sector 24 carpet area 650 sqft status Ready to Move floor 4 out of 4 floors transaction New Property furnishing Semi-Furnished facing East overlooking Garden/Park, Main Road car parking 1 Open bathroom 2 balcony 1 ownership Freehold Newly Constructed Property Newly Constructed Property East Facing Property 2BHK Newly build property for Sale. A House is waiting for a Friendly Family to make it a lovely home.So please come and make his house feel alive once again. read more Contact Agent View Phone No. Share Feedback Garima properties Certified Agent Trusted by Users Genuine Listings Market Knowledge',
#        'Delhi Homes, Rohini Sector 24', 'Rohini Sector 21',
#        'Rohini Sector 22', 'Rohini Sector 20',
# ...

# %%
df.drop('Locality',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Area         1259 non-null   float64
#  1   BHK          1259 non-null   int64
#  2   Bathroom     1259 non-null   float64
#  3   Furnishing   1259 non-null   int64
#  4   Parking      1259 non-null   float64
#  5   Price        1259 non-null   int64
#  6   Status       1259 non-null   object
#  7   Transaction  1259 non-null   object
#  8   Type         1259 non-null   object
#  9   Per_Sqft     1259 non-null   float64
# dtypes: float64(4), int64(3), object(3)
# memory usage: 98.5+ KB

# %%
df['Status'].unique()
# Out:
# array(['Ready_to_move', 'Almost_ready'], dtype=object)

# %%
df['Status']=df['Status'].map({'Ready_to_move':0,'Almost_ready':1})

# %%
df.head()
# Out:
#     Area  BHK  Bathroom  Furnishing  Parking     Price  Status   Transaction  \
# 0  800.0    3       2.0           1      1.0   6500000       0  New_Property
# 1  750.0    2       2.0           1      1.0   5000000       0  New_Property
# 2  950.0    2       2.0           2      1.0  15500000       0        Resale
# 3  600.0    2       2.0           1      1.0   4200000       0        Resale
# 4  650.0    2       2.0           1      1.0   6200000       0  New_Property
#
#             Type  Per_Sqft
# 0  Builder_Floor       0.0
# 1      Apartment    6667.0
# 2      Apartment    6667.0
# 3  Builder_Floor    6667.0
# 4  Builder_Floor    6667.0

# %%
df['Transaction'].unique()
# Out:
# array(['New_Property', 'Resale'], dtype=object)

# %%
df['Transaction']=df['Transaction'].map({'New_Property':0,'Resale':1})

# %%
df.head()
# Out:
#     Area  BHK  Bathroom  Furnishing  Parking     Price  Status  Transaction  \
# 0  800.0    3       2.0           1      1.0   6500000       0            0
# 1  750.0    2       2.0           1      1.0   5000000       0            0
# 2  950.0    2       2.0           2      1.0  15500000       0            1
# 3  600.0    2       2.0           1      1.0   4200000       0            1
# 4  650.0    2       2.0           1      1.0   6200000       0            0
#
#             Type  Per_Sqft
# 0  Builder_Floor       0.0
# 1      Apartment    6667.0
# 2      Apartment    6667.0
# 3  Builder_Floor    6667.0
# 4  Builder_Floor    6667.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Area         1259 non-null   float64
#  1   BHK          1259 non-null   int64
#  2   Bathroom     1259 non-null   float64
#  3   Furnishing   1259 non-null   int64
#  4   Parking      1259 non-null   float64
#  5   Price        1259 non-null   int64
#  6   Status       1259 non-null   int64
#  7   Transaction  1259 non-null   int64
#  8   Type         1259 non-null   object
#  9   Per_Sqft     1259 non-null   float64
# dtypes: float64(4), int64(5), object(1)
# memory usage: 98.5+ KB

# %%
df['Type'].unique()
# Out:
# array(['Builder_Floor', 'Apartment'], dtype=object)

# %%
df['Type']=df['Type'].map({'Builder_Floor':0,'Apartment':1})

# %%
df.head()
# Out:
#     Area  BHK  Bathroom  Furnishing  Parking     Price  Status  Transaction  \
# 0  800.0    3       2.0           1      1.0   6500000       0            0
# 1  750.0    2       2.0           1      1.0   5000000       0            0
# 2  950.0    2       2.0           2      1.0  15500000       0            1
# 3  600.0    2       2.0           1      1.0   4200000       0            1
# 4  650.0    2       2.0           1      1.0   6200000       0            0
#
#    Type  Per_Sqft
# 0     0       0.0
# 1     1    6667.0
# 2     1    6667.0
# 3     0    6667.0
# 4     0    6667.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Area         1259 non-null   float64
#  1   BHK          1259 non-null   int64
#  2   Bathroom     1259 non-null   float64
#  3   Furnishing   1259 non-null   int64
#  4   Parking      1259 non-null   float64
#  5   Price        1259 non-null   int64
#  6   Status       1259 non-null   int64
#  7   Transaction  1259 non-null   int64
#  8   Type         1259 non-null   int64
#  9   Per_Sqft     1259 non-null   float64
# dtypes: float64(4), int64(6)
# memory usage: 98.5 KB

# %%
sns.barplot(x='Parking',y='Bathroom',data=df)
# Out:
# <Axes: xlabel='Parking', ylabel='Bathroom'>

# %%
sns.pairplot(data=df,x_vars='Area', y_vars='Price', kind='scatter')
