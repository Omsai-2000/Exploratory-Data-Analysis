# %% [markdown]
# <a href="https://colab.research.google.com/github/Omsai-2000/Exploratory-Data-Analysis/blob/main/Roster.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing pandas library
import pandas as pd

# %%
df=pd.read_excel('Roster_Aug2023.xls')
df
# Out:
#           Associate 1 Aug 23 Tue 2 Aug 23 Wed 3 Aug 23 Thu 4 Aug 23 Fri  \
# 0     Chhayakant S.      G2\nWFO      G2\nWFH      G2\nWFO      G2\nWFH
# 1               NaN          NaN          NaN          NaN          NaN
# 2  Venkateshwara N.      G2\nWFH      G2\nWFH      G2\nWFH       D\nWFH
# 3           Amit K.      G2\nWFO      G2\nWFO      G2\nWFO      G2\nWFO
# 4         Nagesh S.       D\nWFH       D\nWFH       D\nWFH           WO
# 5          Ayesha S      G1\nWFO      G1\nWFO      G1\nWFO      G1\nWFO
# 6           OmSai Y      G2\nWFO      G2\nWFO      G2\nWFO           WO
#
#   5 Aug 23 Sat 6 Aug 23 Sun 7 Aug 23 Mon 8 Aug 23 Tue 9 Aug 23 Wed  ...  \
# 0           WO           WO      G2\nWFH      G2\nWFO      G2\nWFH  ...
# 1          NaN          NaN          NaN          NaN          NaN  ...
# 2      WO / OC           WO      G2\nWFO      G2\nWFH      G2\nWFO  ...
# 3           WO      WO / OC       D\nWFH       D\nWFH       D\nWFH  ...
# ...

# %%
output_file="omsai"

# %%
result=df.loc[6]
result
# Out:
# Associate        OmSai Y
# 1 Aug 23 Tue     G2\nWFO
# 2 Aug 23 Wed     G2\nWFO
# 3 Aug 23 Thu     G2\nWFO
# 4 Aug 23 Fri          WO
# 5 Aug 23 Sat     G2\nWFH
# 6 Aug 23 Sun          WO
# 7 Aug 23 Mon     G1\nWFO
# 8 Aug 23 Tue     G1\nWFO
# 9 Aug 23 Wed     G1\nWFO
# 10 Aug 23 Thu    G1\nWFO
# 11 Aug 23 Fri    G1\nWFO
# 12 Aug 23 Sat         WO
# 13 Aug 23 Sun         WO
# 14 Aug 23 Mon     D\nWFH
# 15 Aug 23 Tue     D\nWFH
# 16 Aug 23 Wed         WO
# 17 Aug 23 Thu    G1\nWFO
# 18 Aug 23 Fri    G1\nWFO
# 19 Aug 23 Sat         WO
# 20 Aug 23 Sun    G2\nWFH
# 21 Aug 23 Mon    G2\nWFO
# 22 Aug 23 Tue    G2\nWFO
# 23 Aug 23 Wed    G2\nWFO
# 24 Aug 23 Thu     D\nWFH
# 25 Aug 23 Fri     D\nWFH
# 26 Aug 23 Sat         WO
# 27 Aug 23 Sun         WO
# 28 Aug 23 Mon    G1\nWFO
# 29 Aug 23 Tue    G1\nWFO
# 30 Aug 23 Wed    G1\nWFO
# 31 Aug 23 Thu    G2\nWFO
# Name: 6, dtype: object

# %%
output_file = f'RosteringData-Omsai.xlsx'
result.to_excel(output_file, index=False)

# %%
df_ayesha=pd.read_excel('RosteringData-Ayesha.xls')

# %%
df_ayesha
# Out:
#   EmployeeCode       EmployeeName      A2023-08-01      A2023-08-02  \
# 0        IN737  Ms. Shaik  Ayesha  General Shift 1  General Shift 1
#
#        A2023-08-03      A2023-08-04 A2023-08-05 A2023-08-06      A2023-08-07  \
# 0  General Shift 1  General Shift 1  Weekly Off  Weekly Off  General Shift 2
#
#        A2023-08-08  ...      A2023-08-22      A2023-08-23      A2023-08-24  \
# 0  General Shift 2  ...  General Shift 1  General Shift 1  General Shift 1
#
#        A2023-08-25      A2023-08-26 A2023-08-27 A2023-08-28 A2023-08-29  \
# 0  General Shift 1  General Shift 2  Weekly Off     Shift D     Shift D
#
#   A2023-08-30      A2023-08-31
# 0  Weekly Off  General Shift 1
#
# [1 rows x 33 columns]

# %%
data = {
    'EmployeeCode': ['IN737'],
    'EmployeeName': ['Ms. Shaik Ayesha'],
    'A2023-08-01' : ['General Shift 1'],
    'A2023-08-02' : ['General Shift 1']
}
df = pd.DataFrame(data)

# %%
output_file = f'RosteringData-Ayesha.xlsx'
df.to_excel(output_file, index=False)

# %%
existing_file =pd.read_excel("RosteringData-Ayesha.xls")

# %%
existing_file
# Out:
#   EmployeeCode       EmployeeName      A2023-08-01      A2023-08-02  \
# 0        IN737  Ms. Shaik  Ayesha  General Shift 1  General Shift 1
#
#        A2023-08-03      A2023-08-04 A2023-08-05 A2023-08-06      A2023-08-07  \
# 0  General Shift 1  General Shift 1  Weekly Off  Weekly Off  General Shift 2
#
#        A2023-08-08  ...      A2023-08-22      A2023-08-23      A2023-08-24  \
# 0  General Shift 2  ...  General Shift 1  General Shift 1  General Shift 1
#
#        A2023-08-25      A2023-08-26 A2023-08-27 A2023-08-28 A2023-08-29  \
# 0  General Shift 1  General Shift 2  Weekly Off     Shift D     Shift D
#
#   A2023-08-30      A2023-08-31
# 0  Weekly Off  General Shift 1
#
# [1 rows x 33 columns]

# %%
df1=pd.read_excel('Roster_Aug2023.xls')
columns=df1.columns[:12]
columns
# Out:
# Index(['Associate', '1 Aug 23 Tue', '2 Aug 23 Wed', '3 Aug 23 Thu',
#        '4 Aug 23 Fri', '5 Aug 23 Sat', '6 Aug 23 Sun', '7 Aug 23 Mon',
#        '8 Aug 23 Tue', '9 Aug 23 Wed', '10 Aug 23 Thu', '11 Aug 23 Fri'],
#       dtype='object')

# %%
new_data=[['IN737','Ms. Shaik Ayesha','General Shift 1','General Shift 1','General Shift 1','General Shift 1','Weekly Off','Weekly Off','General Shift 2','General Shift 2','General Shift 2','General Shift 2']]

# %%
pd.DataFrame(new_data, columns=columns)
# Out:
#   Associate      1 Aug 23 Tue     2 Aug 23 Wed     3 Aug 23 Thu  \
# 0     IN737  Ms. Shaik Ayesha  General Shift 1  General Shift 1
#
#       4 Aug 23 Fri     5 Aug 23 Sat 6 Aug 23 Sun 7 Aug 23 Mon  \
# 0  General Shift 1  General Shift 1   Weekly Off   Weekly Off
#
#       8 Aug 23 Tue     9 Aug 23 Wed    10 Aug 23 Thu    11 Aug 23 Fri
# 0  General Shift 2  General Shift 2  General Shift 2  General Shift 2

# %%
# New dev for date format change
import pandas as pd

# %%
df_existing_columns=pd.read_excel('Roster_Aug2023.xls')
columns=df_existing_columns.columns[1:32]
columns
# Out:
# Index(['1 Aug 23 Tue', '2 Aug 23 Wed', '3 Aug 23 Thu', '4 Aug 23 Fri',
#        '5 Aug 23 Sat', '6 Aug 23 Sun', '7 Aug 23 Mon', '8 Aug 23 Tue',
#        '9 Aug 23 Wed', '10 Aug 23 Thu', '11 Aug 23 Fri', '12 Aug 23 Sat',
#        '13 Aug 23 Sun', '14 Aug 23 Mon', '15 Aug 23 Tue', '16 Aug 23 Wed',
#        '17 Aug 23 Thu', '18 Aug 23 Fri', '19 Aug 23 Sat', '20 Aug 23 Sun',
#        '21 Aug 23 Mon', '22 Aug 23 Tue', '23 Aug 23 Wed', '24 Aug 23 Thu',
#        '25 Aug 23 Fri', '26 Aug 23 Sat', '27 Aug 23 Sun', '28 Aug 23 Mon',
#        '29 Aug 23 Tue', '30 Aug 23 Wed', '31 Aug 23 Thu'],
#       dtype='object')

# %%
columns.shape
# Out:
# (31,)

# %%
from datetime import datetime

# %%
input_date_str = "1 Aug 23 Tue"
input_date = datetime.strptime(input_date_str, "%d %b %y %a")
output_date_str = "A" + input_date.strftime("%Y-%m-%d")
print(output_date_str)
# Out:
# A2023-08-01

# %%
for i in columns:
  input_date_str = i
  input_date = datetime.strptime(input_date_str, "%d %b %y %a")
  output_date_str = "A" + input_date.strftime("%Y-%m-%d")
  print(output_date_str)
# Out:
# A2023-08-01
# A2023-08-02
# A2023-08-03
# A2023-08-04
# A2023-08-05
# A2023-08-06
# A2023-08-07
# A2023-08-08
# A2023-08-09
# A2023-08-10
# A2023-08-11
# A2023-08-12
# A2023-08-13
# A2023-08-14
# A2023-08-15
# A2023-08-16
# A2023-08-17
# A2023-08-18
# A2023-08-19
# A2023-08-20
# A2023-08-21
# A2023-08-22
# A2023-08-23
# A2023-08-24
# A2023-08-25
# A2023-08-26
# A2023-08-27
# A2023-08-28
# A2023-08-29
# A2023-08-30
# A2023-08-31

# %%
df_existing_columns.loc[2]
# Out:
# Associate        Venkateshwara N.
# 1 Aug 23 Tue              G2\nWFH
# 2 Aug 23 Wed              G2\nWFH
# 3 Aug 23 Thu              G2\nWFH
# 4 Aug 23 Fri               D\nWFH
# 5 Aug 23 Sat              WO / OC
# 6 Aug 23 Sun                   WO
# 7 Aug 23 Mon              G2\nWFO
# 8 Aug 23 Tue              G2\nWFH
# 9 Aug 23 Wed              G2\nWFO
# 10 Aug 23 Thu             G2\nWFO
# 11 Aug 23 Fri              D\nWFH
# 12 Aug 23 Sat                  WO
# 13 Aug 23 Sun                  WO
# 14 Aug 23 Mon             G2\nWFO
# 15 Aug 23 Tue                   H
# 16 Aug 23 Wed             G2\nWFO
# 17 Aug 23 Thu             G2\nWFO
# 18 Aug 23 Fri              D\nWFH
# 19 Aug 23 Sat             WO / OC
# 20 Aug 23 Sun                  WO
# 21 Aug 23 Mon             G2\nWFO
# 22 Aug 23 Tue             G2\nWFO
# 23 Aug 23 Wed             G2\nWFO
# 24 Aug 23 Thu             G2\nWFO
# 25 Aug 23 Fri             G2\nWFH
# 26 Aug 23 Sat             WO / OC
# ...

# %%
row_data=df_existing_columns.loc[2]
row_data.str[0:2]
# Out:
# Associate         Ve
# 1 Aug 23 Tue      G2
# 2 Aug 23 Wed      G2
# 3 Aug 23 Thu      G2
# 4 Aug 23 Fri     D\n
# 5 Aug 23 Sat      WO
# 6 Aug 23 Sun      WO
# 7 Aug 23 Mon      G2
# 8 Aug 23 Tue      G2
# 9 Aug 23 Wed      G2
# 10 Aug 23 Thu     G2
# 11 Aug 23 Fri    D\n
# 12 Aug 23 Sat     WO
# 13 Aug 23 Sun     WO
# 14 Aug 23 Mon     G2
# 15 Aug 23 Tue      H
# 16 Aug 23 Wed     G2
# 17 Aug 23 Thu     G2
# 18 Aug 23 Fri    D\n
# 19 Aug 23 Sat     WO
# 20 Aug 23 Sun     WO
# 21 Aug 23 Mon     G2
# 22 Aug 23 Tue     G2
# 23 Aug 23 Wed     G2
# 24 Aug 23 Thu     G2
# 25 Aug 23 Fri     G2
# 26 Aug 23 Sat     WO
# 27 Aug 23 Sun     WO
# 28 Aug 23 Mon     G2
# 29 Aug 23 Tue     G2
# 30 Aug 23 Wed    D\n
# 31 Aug 23 Thu    D\n
# Name: 2, dtype: object

# %%
row_data = df_existing_columns.loc[2]
sliced_data = row_data.str[0:2]
sliced_data_df = sliced_data.to_frame().reset_index(drop=True)
print(sliced_data_df)
# Out:
#       2
# 0    Ve
# 1    G2
# 2    G2
# 3    G2
# 4   D\n
# 5    WO
# 6    WO
# 7    G2
# 8    G2
# 9    G2
# 10   G2
# 11  D\n
# 12   WO
# 13   WO
# 14   G2
# 15    H
# 16   G2
# 17   G2
# 18  D\n
# 19   WO
# 20   WO
# 21   G2
# 22   G2
# 23   G2
# 24   G2
# 25   G2
# 26   WO
# 27   WO
# 28   G2
# 29   G2
# 30  D\n
# 31  D\n

# %%
sliced_data_df.drop(0, inplace=True)

# %%
sliced_data_df
# Out:
#       2
# 1    G2
# 2    G2
# 3    G2
# 4   D\n
# 5    WO
# 6    WO
# 7    G2
# 8    G2
# 9    G2
# 10   G2
# 11  D\n
# 12   WO
# 13   WO
# 14   G2
# 15    H
# 16   G2
# 17   G2
# 18  D\n
# 19   WO
# 20   WO
# 21   G2
# 22   G2
# 23   G2
# 24   G2
# 25   G2
# 26   WO
# 27   WO
# 28   G2
# 29   G2
# 30  D\n
# 31  D\n

# %%
sliced_data_df
df= pd.DataFrame(sliced_data_df)
df
# Out:
#       2
# 1    G2
# 2    G2
# 3    G2
# 4   D\n
# 5    WO
# 6    WO
# 7    G2
# 8    G2
# 9    G2
# 10   G2
# 11  D\n
# 12   WO
# 13   WO
# 14   G2
# 15    H
# 16   G2
# 17   G2
# 18  D\n
# 19   WO
# 20   WO
# 21   G2
# 22   G2
# 23   G2
# 24   G2
# 25   G2
# 26   WO
# 27   WO
# 28   G2
# 29   G2
# 30  D\n
# 31  D\n

# %%
for i in columns:
  input_date_str = i
  input_date = datetime.strptime(input_date_str, "%d %b %y %a")
  output_date_str = "A" + input_date.strftime("%Y-%m-%d")
  print(output_date_str)
df = pd.DataFrame({'Date': [output_date_str]})
df
# Out:
# A2023-08-01
# A2023-08-02
# A2023-08-03
# A2023-08-04
# A2023-08-05
# A2023-08-06
# A2023-08-07
# A2023-08-08
# A2023-08-09
# A2023-08-10
# A2023-08-11
# A2023-08-12
# A2023-08-13
# A2023-08-14
# A2023-08-15
# A2023-08-16
# A2023-08-17
# A2023-08-18
# A2023-08-19
# A2023-08-20
# A2023-08-21
# A2023-08-22
# A2023-08-23
# A2023-08-24
# A2023-08-25
# A2023-08-26
# A2023-08-27
# A2023-08-28
# A2023-08-29
# A2023-08-30
# A2023-08-31
#           Date
# 0  A2023-08-31

# %%
def map_shift_code(value):
    if value == 'G1':
        return 'General Shift 1'
    elif value == 'G2':
        return 'General Shift 2'
    elif value == 'D\n':
        return 'Shift D'
    elif value == 'WO':
        return 'Weekly Off'
    else:
        return value

df[2] = df[2].apply(map_shift_code)
print(df)
# Out:
#                   2        dates
# 1   General Shift 2  A2023-08-31
# 2   General Shift 2  A2023-08-31
# 3   General Shift 2  A2023-08-31
# 4           Shift D  A2023-08-31
# 5        Weekly Off  A2023-08-31
# 6        Weekly Off  A2023-08-31
# 7   General Shift 2  A2023-08-31
# 8   General Shift 2  A2023-08-31
# 9   General Shift 2  A2023-08-31
# 10  General Shift 2  A2023-08-31
# 11          Shift D  A2023-08-31
# 12       Weekly Off  A2023-08-31
# 13       Weekly Off  A2023-08-31
# 14  General Shift 2  A2023-08-31
# 15                H  A2023-08-31
# 16  General Shift 2  A2023-08-31
# 17  General Shift 2  A2023-08-31
# 18          Shift D  A2023-08-31
# 19       Weekly Off  A2023-08-31
# 20       Weekly Off  A2023-08-31
# 21  General Shift 2  A2023-08-31
# 22  General Shift 2  A2023-08-31
# 23  General Shift 2  A2023-08-31
# 24  General Shift 2  A2023-08-31
# 25  General Shift 2  A2023-08-31
# 26       Weekly Off  A2023-08-31
# 27       Weekly Off  A2023-08-31
# ...

# %%
df = df.rename(columns={2: 'Venkat'})

# %%
df
# Out:
#              Venkat        dates
# 1   General Shift 2  A2023-08-31
# 2   General Shift 2  A2023-08-31
# 3   General Shift 2  A2023-08-31
# 4           Shift D  A2023-08-31
# 5        Weekly Off  A2023-08-31
# 6        Weekly Off  A2023-08-31
# 7   General Shift 2  A2023-08-31
# 8   General Shift 2  A2023-08-31
# 9   General Shift 2  A2023-08-31
# 10  General Shift 2  A2023-08-31
# 11          Shift D  A2023-08-31
# 12       Weekly Off  A2023-08-31
# 13       Weekly Off  A2023-08-31
# 14  General Shift 2  A2023-08-31
# 15                H  A2023-08-31
# 16  General Shift 2  A2023-08-31
# 17  General Shift 2  A2023-08-31
# 18          Shift D  A2023-08-31
# 19       Weekly Off  A2023-08-31
# 20       Weekly Off  A2023-08-31
# 21  General Shift 2  A2023-08-31
# 22  General Shift 2  A2023-08-31
# 23  General Shift 2  A2023-08-31
# 24  General Shift 2  A2023-08-31
# 25  General Shift 2  A2023-08-31
# 26       Weekly Off  A2023-08-31
# 27       Weekly Off  A2023-08-31
# ...

# %%
df = df[['dates', 'Venkat']]

# %%
output_file = f'RosteringData-venkat.xlsx'
df.to_excel(output_file, index=False)

# %%
df_existing_columns=pd.read_excel('Roster_Aug2023.xls')
columns=df_existing_columns.columns[1:32]
data = []
for date_str in columns:
    input_date = datetime.strptime(date_str, "%d %b %y %a")
    output_date_str = "A" + input_date.strftime("%Y-%m-%d")
    data.append({'Date_Column': output_date_str})


df1 = pd.DataFrame(data)
df1
# Out:
#     Date_Column
# 0   A2023-08-01
# 1   A2023-08-02
# 2   A2023-08-03
# 3   A2023-08-04
# 4   A2023-08-05
# 5   A2023-08-06
# 6   A2023-08-07
# 7   A2023-08-08
# 8   A2023-08-09
# 9   A2023-08-10
# 10  A2023-08-11
# 11  A2023-08-12
# 12  A2023-08-13
# 13  A2023-08-14
# 14  A2023-08-15
# 15  A2023-08-16
# 16  A2023-08-17
# 17  A2023-08-18
# 18  A2023-08-19
# 19  A2023-08-20
# 20  A2023-08-21
# 21  A2023-08-22
# 22  A2023-08-23
# 23  A2023-08-24
# 24  A2023-08-25
# 25  A2023-08-26
# 26  A2023-08-27
# 27  A2023-08-28
# 28  A2023-08-29
# 29  A2023-08-30
# 30  A2023-08-31

# %%
row_data = df_existing_columns.loc[2]
sliced_data = row_data.str[0:2]
sliced_data_df = sliced_data.to_frame().reset_index(drop=True)
print(sliced_data_df)
sliced_data_df.drop(0, inplace=True)
df2= pd.DataFrame(sliced_data_df)
df2
# Out:
#       2
# 0    Ve
# 1    G2
# 2    G2
# 3    G2
# 4   D\n
# 5    WO
# 6    WO
# 7    G2
# 8    G2
# 9    G2
# 10   G2
# 11  D\n
# 12   WO
# 13   WO
# 14   G2
# 15    H
# 16   G2
# 17   G2
# 18  D\n
# 19   WO
# 20   WO
# 21   G2
# 22   G2
# 23   G2
# 24   G2
# 25   G2
# 26   WO
# 27   WO
# 28   G2
# 29   G2
# 30  D\n
# 31  D\n
#       2
# 1    G2
# 2    G2
# 3    G2
# 4   D\n
# 5    WO
# 6    WO
# 7    G2
# 8    G2
# 9    G2
# 10   G2
# 11  D\n
# 12   WO
# 13   WO
# 14   G2
# 15    H
# 16   G2
# 17   G2
# 18  D\n
# 19   WO
# 20   WO
# 21   G2
# 22   G2
# 23   G2
# 24   G2
# 25   G2
# 26   WO
# 27   WO
# 28   G2
# 29   G2
# 30  D\n
# 31  D\n

# %%
def map_shift_code(value):
    if value == 'G1':
        return 'General Shift 1'
    elif value == 'G2':
        return 'General Shift 2'
    elif value == 'D\n':
        return 'Shift D'
    elif value == 'WO':
        return 'Weekly Off'
    else:
        return value

df2[2] = df2[2].apply(map_shift_code)
print(df2)
# Out:
#                   2
# 1   General Shift 2
# 2   General Shift 2
# 3   General Shift 2
# 4           Shift D
# 5        Weekly Off
# 6        Weekly Off
# 7   General Shift 2
# 8   General Shift 2
# 9   General Shift 2
# 10  General Shift 2
# 11          Shift D
# 12       Weekly Off
# 13       Weekly Off
# 14  General Shift 2
# 15                H
# 16  General Shift 2
# 17  General Shift 2
# 18          Shift D
# 19       Weekly Off
# 20       Weekly Off
# 21  General Shift 2
# 22  General Shift 2
# 23  General Shift 2
# 24  General Shift 2
# 25  General Shift 2
# 26       Weekly Off
# 27       Weekly Off
# 28  General Shift 2
# 29  General Shift 2
# 30          Shift D
# 31          Shift D

# %%
df2 = df2.rename(columns={2: 'Venkat'})

# %%
df2
# Out:
#              Venkat
# 1   General Shift 2
# 2   General Shift 2
# 3   General Shift 2
# 4           Shift D
# 5        Weekly Off
# 6        Weekly Off
# 7   General Shift 2
# 8   General Shift 2
# 9   General Shift 2
# 10  General Shift 2
# 11          Shift D
# 12       Weekly Off
# 13       Weekly Off
# 14  General Shift 2
# 15                H
# 16  General Shift 2
# 17  General Shift 2
# 18          Shift D
# 19       Weekly Off
# 20       Weekly Off
# 21  General Shift 2
# 22  General Shift 2
# 23  General Shift 2
# 24  General Shift 2
# 25  General Shift 2
# 26       Weekly Off
# 27       Weekly Off
# 28  General Shift 2
# 29  General Shift 2
# 30          Shift D
# 31          Shift D

# %%
df1.shape
# Out:
# (31, 1)

# %%
df2.shape
# Out:
# (31, 1)

# %%
pd.concat([df1,df2],axis=1)
# Out:
#     Date_Column           Venkat
# 0   A2023-08-01  General Shift 2
# 1   A2023-08-02  General Shift 2
# 2   A2023-08-03  General Shift 2
# 3   A2023-08-04          Shift D
# 4   A2023-08-05       Weekly Off
# 5   A2023-08-06       Weekly Off
# 6   A2023-08-07  General Shift 2
# 7   A2023-08-08  General Shift 2
# 8   A2023-08-09  General Shift 2
# 9   A2023-08-10  General Shift 2
# 10  A2023-08-11          Shift D
# 11  A2023-08-12       Weekly Off
# 12  A2023-08-13       Weekly Off
# 13  A2023-08-14  General Shift 2
# 14  A2023-08-15                H
# 15  A2023-08-16  General Shift 2
# 16  A2023-08-17  General Shift 2
# 17  A2023-08-18          Shift D
# 18  A2023-08-19       Weekly Off
# 19  A2023-08-20       Weekly Off
# 20  A2023-08-21  General Shift 2
# 21  A2023-08-22  General Shift 2
# 22  A2023-08-23  General Shift 2
# 23  A2023-08-24  General Shift 2
# 24  A2023-08-25  General Shift 2
# 25  A2023-08-26       Weekly Off
# 26  A2023-08-27       Weekly Off
# ...

# %%
df1.reset_index(drop=True, inplace=True)
df2.reset_index(drop=True, inplace=True)

merged_df = pd.concat([df1, df2], axis=1)

# %%
merged_df.columns = range(merged_df.shape[1])
merged_df
# Out:
#               0                1
# 0   A2023-08-01  General Shift 2
# 1   A2023-08-02  General Shift 2
# 2   A2023-08-03  General Shift 2
# 3   A2023-08-04          Shift D
# 4   A2023-08-05       Weekly Off
# 5   A2023-08-06       Weekly Off
# 6   A2023-08-07  General Shift 2
# 7   A2023-08-08  General Shift 2
# 8   A2023-08-09  General Shift 2
# 9   A2023-08-10  General Shift 2
# 10  A2023-08-11          Shift D
# 11  A2023-08-12       Weekly Off
# 12  A2023-08-13       Weekly Off
# 13  A2023-08-14  General Shift 2
# 14  A2023-08-15                H
# 15  A2023-08-16  General Shift 2
# 16  A2023-08-17  General Shift 2
# 17  A2023-08-18          Shift D
# 18  A2023-08-19       Weekly Off
# 19  A2023-08-20       Weekly Off
# 20  A2023-08-21  General Shift 2
# 21  A2023-08-22  General Shift 2
# 22  A2023-08-23  General Shift 2
# 23  A2023-08-24  General Shift 2
# 24  A2023-08-25  General Shift 2
# 25  A2023-08-26       Weekly Off
# 26  A2023-08-27       Weekly Off
# ...

# %%
data1 = {
    'EmployeeCode': ['IN737'],
    'EmployeeName': ['Venkat']
}
df3 = pd.DataFrame(data1)
df3
# Out:
#   EmployeeCode EmployeeName
# 0        IN737       Venkat

# %%
transposed_df = merged_df.T

# %%
transposed_df
# Out:
#                 0                1                2            3   \
# 0      A2023-08-01      A2023-08-02      A2023-08-03  A2023-08-04
# 1  General Shift 2  General Shift 2  General Shift 2      Shift D
#
#             4            5                6                7   \
# 0  A2023-08-05  A2023-08-06      A2023-08-07      A2023-08-08
# 1   Weekly Off   Weekly Off  General Shift 2  General Shift 2
#
#                 8                9   ...               21               22  \
# 0      A2023-08-09      A2023-08-10  ...      A2023-08-22      A2023-08-23
# 1  General Shift 2  General Shift 2  ...  General Shift 2  General Shift 2
#
#                 23               24           25           26  \
# 0      A2023-08-24      A2023-08-25  A2023-08-26  A2023-08-27
# 1  General Shift 2  General Shift 2   Weekly Off   Weekly Off
#
#                 27               28           29           30
# 0      A2023-08-28      A2023-08-29  A2023-08-30  A2023-08-31
# ...
